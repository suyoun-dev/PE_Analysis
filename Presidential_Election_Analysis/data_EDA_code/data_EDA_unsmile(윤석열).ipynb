# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib
import matplotlib_inline
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.font_manager as fm
import collections

# %%
df = pd.read_csv('./윤석열/윤석열_unsmile.csv',encoding='utf-8')

# %%
label = ['여성/가족', '남성', '성소수자', '인종/국적', '연령', '지역', '종교', '기타 혐오', '악플/욕설', 'clean']

# %%
stats = []
for i in label:
    stats.append(df[i].sum())

# %%
plt.rcParams['font.family'] = "NanumGothic"
plt.rcParams['axes.unicode_minus'] = False

# %%
#wedgeprops={'width': 0.5, 'edgecolor': 'w', 'linewidth': 2}
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#2962FF', '#00c853', '#f57f17', '#ffea00', '#1De9B6', '#b39ddb']
plt.axis=('equal')
plt.title('윤석열')
plt.pie(stats, labels=label, autopct='%.2f%%', colors=colors)
plt.show()

# %%
# 카테고리별로 점수가 높은 순서대로 정렬
df_woman = df.sort_values(by='여성/가족', ascending=False).groupby('text').head(10)
df_man = df.sort_values(by='남성', ascending=False).groupby('text').head(10)
df_region = df.sort_values(by='지역', ascending=False).groupby('text').head(10)
df_queer = df.sort_values(by='성소수자', ascending=False).groupby('text').head(10)
df_religion = df.sort_values(by='종교', ascending=False).groupby('text').head(10)

# %%
df_woman.head(20)
# Out:
#          Datetime                                               text  label  \
# 12058  2022-02-21  좌빨이 페미겠지 ㅋㅋㅋㅋㅋㅋ 윤석열이 왜 싫을까 페미친화적이지 않으니까 그렇지 ㅋㅋ...      0
# 15610  2022-02-24  걍 이재명이 한녀 손 들어준 거 자체도 지극히 이성적이고 대단한 거 같음 막말로 이...      0
# 10338  2022-02-19  여자가 합격하면 공정과 상식이 무너졌다는 윤석열 그래도 찬양하는 여성단체와 가짜 페...      0
# 15886  2022-02-24  한녀들아 윤석열 찍지마라 윤석열이 대통령 되는순간 우리나라 여성 인권은 이슬람처럼 ...      0
# 25951  2022-03-06  여성가족부가 존재해야 하는 이유 윤석열의 여가부폐지가 악마들이나 내놓을 수 있는 공...      1
# 13451  2022-02-22  페미니즘병신집단 아님 윤석열이 대통령되면 여자를 어떻게 생각할지두렵다 카는데 니들은...      0
# 8453   2022-02-17  페미니즘이 위헌이라는 윤석열 vs 추적단불꽃님 박지현님과 함께 일하는 이재명 무조건...      1
# 18480  2022-02-27  속보 선택적 분노 말고는 모르고 꿘충에게 놀아나는 꼴페미년들 꼴보기 싫은 애묘인 협...      0
# 4962   2022-02-13  민주당 네거티브 하는거봐라 김건희 윤석열부부한테 마이클잭슨부터 자녀이야기 니네가 페...      0
# 24292  2022-03-05  트위터에서 윤석열 찍었다고 말하고 이재명 뽑는 한녀들 한심하다 말하는게 끈기 얘기까...      0
# 15328  2022-02-24                 페미니스트면서 여가부폐지 웅앵하는 윤석열 지지하는 사짜가 있다      0
# 8364   2022-02-17  아니 아무리 찢재명 뒤가 구려도 당장 페미니즘은 정신병 페미니즘은 반헌법적사상 공식...      0
# 19790  2022-02-28  윤석열 여가부 폐지 하나로 여성인권 후퇴한다는 트페미들은 윤석열 여성 정책에 대해서...      1
# 15588  2022-02-24  대선 D 13 윤석열 후보의 여성가족부 폐지 공약을 제대로 아는 사람이 없다 국민의...      0
# 19342  2022-02-28    윤석열 30조 성인지 예산 국방비로 대체하겠다 선언 #윤석열 #페미니즘 #shorts      0
# 496    2022-02-09  페미 찢갈이들 좌표찍고 몰려오고 있습니다 외고였던 조민을 수사한게 윤석열 후보인데 ...      0
# 6752   2022-02-15  안치환이 손가락 말고 가르키는 곳을 보라고한다 가르치는 곳을 보니 여가부가 그렇게 ...      0
# 2328   2022-02-11  윤석열의 곤란한 답변 자르고 깐부해주는것 보시라 오늘 2차 토론에서도 보여주듯이 자...      0
# 10260  2022-02-19  지금이야 페미들 탈코해서 머리채 안잡히지만 윤석열 당선 이후엔 어떤 혐오범죄가 잇따...      1
# 27665  2022-03-08                윤석열 머릿속에선 페미니즘이 볼드모트고 페미니스트가 죽먹자인거임      1
#
#        여성/가족    남성  성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 12058   0.94  0.01  0.02   0.06  0.02  0.09  0.04   0.15   0.06   0.05
# 15610   0.93  0.06  0.02   0.06  0.01  0.03  0.03   0.04   0.04   0.04
# 10338   0.93  0.01  0.03   0.05  0.02  0.03  0.03   0.10   0.05   0.06
# 15886   0.93  0.03  0.02   0.17  0.02  0.03  0.13   0.07   0.02   0.03
# 25951   0.93  0.02  0.02   0.05  0.02  0.02  0.01   0.06   0.05   0.07
# 13451   0.92  0.02  0.03   0.03  0.02  0.02  0.03   0.07   0.05   0.03
# 8453    0.92  0.04  0.06   0.03  0.01  0.02  0.02   0.06   0.04   0.05
# 18480   0.92  0.03  0.02   0.02  0.03  0.02  0.02   0.06   0.05   0.04
# 4962    0.92  0.01  0.02   0.05  0.02  0.04  0.03   0.13   0.09   0.05
# 24292   0.92  0.05  0.01   0.03  0.02  0.02  0.03   0.04   0.05   0.05
# 15328   0.91  0.03  0.02   0.03  0.02  0.01  0.02   0.06   0.08   0.07
# 8364    0.91  0.06  0.02   0.04  0.01  0.02  0.02   0.03   0.04   0.05
# 19790   0.91  0.02  0.02   0.03  0.02  0.01  0.01   0.04   0.05   0.12
# 15588   0.91  0.02  0.02   0.04  0.02  0.02  0.01   0.06   0.06   0.10
# 19342   0.91  0.02  0.03   0.03  0.01  0.02  0.02   0.05   0.04   0.07
# 496     0.91  0.02  0.02   0.04  0.02  0.02  0.01   0.11   0.08   0.06
# 6752    0.91  0.05  0.02   0.03  0.02  0.02  0.02   0.04   0.04   0.05
# 2328    0.90  0.02  0.01   0.03  0.02  0.03  0.02   0.06   0.08   0.07
# 10260   0.90  0.04  0.02   0.04  0.01  0.01  0.01   0.04   0.05   0.07
# 27665   0.90  0.02  0.02   0.03  0.01  0.01  0.02   0.04   0.06   0.08

# %%
df_religion.head(20)
# Out:
#          Datetime                                               text  label  \
# 1930   2022-02-10  꼴에 성경 한 두번 읽고 예수 믿는다고 교회다니며 윤석열 지지하는 개독색히들 보거라...      0
# 3701   2022-02-12          정답입니다 신천지의 아들 윤석열 건진법사 딸 김건희소가죽 사이비 무당 박멸      1
# 15400  2022-02-24  문 정부서 한국교회 가장 불행 목사 777명 윤석열 지지선언 다음 뉴스 현금 장사치...      0
# 1087   2022-02-10                누가 언제 윤석열이 개독과 수꼴의 급폭망을 가져온다고 예언했던가      0
# 3109   2022-02-12  윤석열 진짜 말 못한다 저게 어딜 봐서 토론이냐 말 돌리면서 웅앵웅 하는 개저한남의 표본      0
# 677    2022-02-09  이대남들아 윤석열 후보에게 표를 주면 군대를 가야 돼 그 사람은 너희에게 주술로 전...      0
# 23776  2022-03-04                                 내 주위 한남들 다 윤석열 찍는대      0
#
#        여성/가족    남성  성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 24445   0.03  0.95  0.04   0.09  0.04  0.03  0.02   0.03   0.05   0.03
# 25674   0.04  0.95  0.03   0.07  0.02  0.02  0.03   0.02   0.06   0.04
# 21353   0.04  0.94  0.02   0.03  0.03  0.02  0.03   0.02   0.08   0.04
# 26759   0.07  0.94  0.02   0.05  0.03  0.02  0.02   0.02   0.05   0.04
# 17924   0.05  0.93  0.02   0.03  0.03  0.02  0.02   0.03   0.08   0.04
# 24041   0.03  0.93  0.03   0.06  0.03  0.05  0.01   0.02   0.05   0.06
# 23286   0.03  0.93  0.02   0.04  0.04  0.02  0.02   0.02   0.04   0.06
# 19069   0.05  0.93  0.02   0.04  0.03  0.02  0.02   0.02   0.05   0.04
# 9750    0.06  0.93  0.02   0.02  0.03  0.03  0.02   0.02   0.05   0.04
# 23148   0.03  0.93  0.03   0.05  0.04  0.02  0.02   0.03   0.05   0.03
# 24728   0.04  0.93  0.02   0.04  0.03  0.02  0.02   0.02   0.07   0.06
# 8766    0.04  0.92  0.02   0.04  0.02  0.02  0.02   0.02   0.06   0.04
# 23561   0.04  0.92  0.02   0.04  0.04  0.10  0.02   0.02   0.05   0.06
# 8320    0.08  0.92  0.02   0.03  0.02  0.02  0.02   0.02   0.05   0.04
# 5732    0.07  0.92  0.02   0.04  0.03  0.02  0.02   0.01   0.05   0.05
# 10929   0.04  0.92  0.03   0.04  0.04  0.02  0.01   0.04   0.06   0.04
# 23387   0.07  0.92  0.01   0.05  0.03  0.02  0.02   0.02   0.05   0.03
# 3109    0.02  0.92  0.02   0.05  0.04  0.02  0.02   0.02   0.07   0.04
# 677     0.03  0.91  0.03   0.08  0.03  0.02  0.01   0.03   0.05   0.06
# 23776   0.04  0.91  0.02   0.03  0.03  0.02  0.02   0.01   0.07   0.05

# %%
df_region.head(20)
# Out:
#          Datetime                                               text  label  \
# 24952  2022-03-05  윤석열이나 이준석을 더 경계하는건 여성이라서도 있지만 전라도 사람으로서도 남초커뮤 ...      0
# 13543  2022-02-22  모처럼 호남출신으로 전국구 인물이었던 이낙연 전라도 순천에서 개망신 전라디언들은 경...      0
# 19529  2022-02-28  동서갈등 해소를 위해 전라디언이 모여 윤석열 지지하자 세계에서 단체 위원회등이 제일...      0
# 13947  2022-02-22                                       라도 특 윤석열 지지함      0
# 9483   2022-02-18  전라 들 이런 후보를 내편이라 찍었다간 개 돼지 취급당할까 심히 우려된다 전라디언이...      0
# 7209   2022-02-16                                  #윤석열 #광주 #꼴등 #거짓말      0
# 2854   2022-02-11  온갖 한국의 악이 다 모여있는 국민의힘당 윤석열 기곡교 신천지 여혐남 사람죽이는 기...      0
# 26009  2022-03-07  냄비근성의 조센징들 그들은 또 윤석열을 찍읍니다 그들은 그들만의 지역 동네 세상에 ...      0
# 7815   2022-02-16  대구 이 썩은 수사기관 이 걸레 경찰서 이 씨발것들과대구지방 이 썩은 검찰청과이 씨...      0
# 15064  2022-02-24  전라도 문디들이 민주당을 살리자고 이재명 문디를 지지하는 것 이재명 지지율이 올라 ...      0
# 14036  2022-02-23  아직도 윤석열 두둔하고픈 마음은 1도 없지만 광주출신이고 거의 평생을 전라도 사람으...      0
# 25014  2022-03-06  우덜동네 즐라도 사전투표율이 50 를 넘었단다 이게 뭔 뜻인지 짐작이 간다 거기다 ...      0
# 2511   2022-02-11  이재명 사드 어디에 설치하냐 윤석열 수도권 방어 유리 지점에 다음 뉴스 대선토론에서...      0
# 3897   2022-02-12                                    윤석열 후보의 전라북도 공약      0
# 18325  2022-02-27  여기 부산 대부분의 윤석열 지지하는 종자들은 무조건 국짐 지지하는 것들이며 전라도가...      0
# 26098  2022-03-07  근데 윤석열 뽑는 남자들하곤 상종도 하기 싫음 특히 2030 걔넨 그냥 여자가 싫고...      0
# 10601  2022-02-19  민주화 된지가 언제인데 지금까지 투쟁의식 강화니 약화니 그딴소리 나는 거 그니까 광...      0
# 722    2022-02-09  이나라를 1000년넘게 망쳐온 씹썌갱상도것들이 이번 딱한번 나쁜새끼 이재명지지율이 ...      0
# 15616  2022-02-24  유사이래 대한민국 최고의 양아치집단 민좃당 호남1500만이 지금껏 다 알고도 속아준...      0
# 26433  2022-03-07  똥꾸녘 거렁뱅이 비천 국힘 특보가 전라도인 에 한 말 신광조 국힘 선대위 균형발전특...      0
#
#        여성/가족    남성  성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 24952   0.05  0.03  0.03   0.06  0.02  0.96  0.02   0.04   0.03   0.06
# 13543   0.03  0.02  0.02   0.08  0.02  0.95  0.03   0.04   0.03   0.05
# 19529   0.04  0.02  0.02   0.08  0.02  0.95  0.02   0.05   0.03   0.05
# 13947   0.02  0.02  0.02   0.05  0.02  0.94  0.03   0.03   0.03   0.07
# 9483    0.02  0.02  0.02   0.07  0.02  0.94  0.03   0.04   0.04   0.04
# 7209    0.02  0.02  0.04   0.04  0.02  0.94  0.03   0.05   0.04   0.04
# 2854    0.05  0.04  0.05   0.19  0.02  0.94  0.20   0.07   0.02   0.03
# 26009   0.04  0.05  0.02   0.14  0.03  0.94  0.02   0.04   0.03   0.03
# 7815    0.02  0.03  0.03   0.06  0.02  0.94  0.04   0.04   0.03   0.03
# 15064   0.02  0.02  0.02   0.05  0.02  0.94  0.03   0.03   0.03   0.07
# 14036   0.01  0.01  0.02   0.06  0.02  0.93  0.02   0.04   0.04   0.06
# 25014   0.02  0.02  0.02   0.04  0.02  0.93  0.02   0.03   0.04   0.08
# 2511    0.02  0.02  0.03   0.03  0.02  0.93  0.02   0.08   0.06   0.05
# 3897    0.02  0.02  0.03   0.04  0.02  0.93  0.02   0.02   0.03   0.12
# 18325   0.07  0.02  0.03   0.04  0.11  0.93  0.01   0.13   0.05   0.04
# 26098   0.21  0.04  0.04   0.02  0.07  0.93  0.02   0.11   0.04   0.04
# 10601   0.01  0.01  0.02   0.03  0.03  0.93  0.03   0.08   0.06   0.07
# 722     0.02  0.02  0.02   0.05  0.02  0.93  0.03   0.03   0.04   0.03
# 15616   0.02  0.01  0.02   0.05  0.01  0.93  0.03   0.07   0.07   0.04
# 26433   0.02  0.02  0.02   0.06  0.02  0.93  0.02   0.05   0.05   0.05

# %%
df_queer.head(20)
# Out:
#          Datetime                                               text  label  \
# 14407  2022-02-23  이재명 당선되고 사회투쟁으로 성소수자 권리 쟁취하기 vs 윤석열 당선되고 퀴어무당집...      1
# 8215   2022-02-17        윤석열이 대통령이 되면 한국의 성소수자들은 생존권을 확실히 위협받게 될 겁니다      0
# 14427  2022-02-23  저는 성소수자 차별을 적극 지지합니다 오히려 윤석열 후보가 진보적인 정책을 편 것이...      0
# 14450  2022-02-23  이재명이 저지랄해도 윤석열 막겠다고 뽑아야되나 고민하고 있는 성소수 인생 이미 비참...      0
# 23090  2022-03-04  나는 화낼 가치도 없는 사람한테 관계를 개선하기 위해 내 감정 소모해서 화낼 필요 ...      0
# 14485  2022-02-23  국제앰네스티 한국지부의 질문은 성소수자 LGBTI 권리 젠더 평등 기후정의 북한 인...      1
# 14348  2022-02-23  아니 근데 진짜 트좍 말마따나 윤석열 성소수 권리 지지선언 일부추진은 뭐임 성소수도...      0
# 14771  2022-02-23  정말 성소수자와 차별금지법을 원하는 안전한 사회를 원하는 여성의 목소리를 듣게 할 ...      0
# 13333  2022-02-22  대통령 윤석열 총리 원희룡 검찰총장 한동훈 개좋은데 재명이 똥꼬까지 탈탈 털릴거아냐...      0
# 15456  2022-02-24  윤석열이 진짜 쳐다 볼 수준도 못 된다는 거 아는데 그 와중에 제발 다른 데 뽑지 ...      0
# 14177  2022-02-23  게이도 그 성별 그 연령대니까 생각이 짧아서 윤석열이 대충 답변한 걸 진지하게 받아...      0
# 14758  2022-02-23  진짜 개빡치게 성소수자 유권자 뭐라할시간에 이재명 맘에 안들어서 윤석열뽑겠다는 니네...      0
# 10598  2022-02-19  윤석열 후보는 물백신 맞았나요 코로나 백신 3차 접종하신 분들은 병원에 가셔서 에이...      0
# 14298  2022-02-23  이재명이 현실적으로 답변한거긴 개뿔 아직도 성소수자인권 밑바닥인 한국을 보여주는거지...      0
# 14858  2022-02-23  나는 오히려 윤석열이 성소수자 권리에 대해 일부 추진 이라고 말한 이유와 계획이 매...      1
# 14642  2022-02-23  전화영어 오늘의 주제는 대선개입이었다 당연히 우리나라 대선으로 화제가 돌려졌고 나는...      0
# 11551  2022-02-20  여성과 퀴어가 이재명을 뽑는다면 윤석열은 절대 안 된다는 심정으로 거의 자해에 가까...      0
# 23858  2022-03-04  윤석열의 민주주의는 노동자들이 죽어나가고 소수자들이 차별당하고 여성들이 위험에 처하...      0
# 13635  2022-02-22  심상정의 1분이 부러웠나보다 성소수자와 성폭력피해생존자여성 장애인을 호명하는 심상정...      0
# 24225  2022-03-05  하 내남동생은 대체뭘까 갑자기 트 레저분들의신곡을 부르고다니질않나 갑자기내방에쳐들어...      0
#
#        여성/가족    남성  성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 14407   0.03  0.02  0.88   0.02  0.01  0.02  0.02   0.04   0.04   0.07
# 8215    0.03  0.02  0.86   0.02  0.02  0.02  0.02   0.04   0.04   0.07
# 14427   0.03  0.02  0.85   0.02  0.01  0.02  0.02   0.04   0.03   0.07
# 14450   0.03  0.35  0.82   0.05  0.02  0.02  0.02   0.06   0.04   0.03
# 23090   0.02  0.02  0.79   0.02  0.01  0.01  0.02   0.03   0.06   0.11
# 14485   0.05  0.02  0.76   0.04  0.01  0.01  0.01   0.05   0.04   0.16
# 14348   0.03  0.01  0.76   0.01  0.01  0.01  0.02   0.03   0.09   0.12
# 14771   0.03  0.01  0.75   0.01  0.01  0.02  0.01   0.05   0.05   0.11
# 13333   0.01  0.02  0.73   0.02  0.01  0.01  0.02   0.03   0.13   0.08
# 15456   0.01  0.01  0.66   0.04  0.02  0.02  0.12   0.16   0.22   0.02
# 14177   0.02  0.01  0.64   0.01  0.01  0.01  0.01   0.03   0.11   0.22
# 14758   0.03  0.01  0.63   0.02  0.01  0.02  0.02   0.07   0.30   0.03
# 10598   0.02  0.02  0.56   0.01  0.01  0.01  0.01   0.04   0.16   0.31
# 14298   0.02  0.01  0.51   0.02  0.01  0.01  0.03   0.06   0.33   0.03
# 14858   0.02  0.01  0.51   0.01  0.01  0.01  0.01   0.03   0.07   0.28
# 14642   0.03  0.01  0.46   0.01  0.01  0.01  0.01   0.04   0.11   0.34
# 11551   0.20  0.01  0.44   0.02  0.01  0.04  0.01   0.18   0.15   0.05
# 23858   0.11  0.01  0.43   0.01  0.01  0.01  0.01   0.23   0.41   0.05
# 13635   0.13  0.01  0.42   0.01  0.01  0.01  0.01   0.09   0.07   0.17
# 24225   0.02  0.01  0.42   0.03  0.00  0.01  0.03   0.05   0.27   0.12

# %%
# 0.6이상인 텍스트들만 추출
df_woman = df_woman[df_woman['여성/가족'] >= 0.6]
df_man = df_man[df_man['남성'] >= 0.6]
df_region = df_region[df_region['지역'] >= 0.6]
df_queer = df_queer[df_queer['성소수자'] >= 0.6]
df_religion = df_religion[df_religion['종교'] >= 0.6]

# %%
# 전체 갯수 확인
print(len(df_woman))
print(len(df_man))
print(len(df_region))
print(len(df_queer))
print(len(df_religion))
# Out:
# 224
# 106
# 281
# 12
# 153

# %%
print('여성/가족 긍정 리뷰 갯수: {}'.format(df_woman['label'].value_counts()[1]))
print('여성/가족 부정 리뷰 갯수: {}'.format(df_woman['label'].value_counts()[0]))
print('남성 긍정 리뷰 갯수: {}'.format(df_man['label'].value_counts()[1]))
print('남성 부정 리뷰 갯수: {}'.format(df_man['label'].value_counts()[0]))
print('지역 긍정 리뷰 갯수: {}'.format(df_region['label'].value_counts()[1]))
print('지역 부정 리뷰 갯수: {}'.format(df_region['label'].value_counts()[0]))
print('성소수자 긍정 리뷰 갯수: {}'.format(df_queer['label'].value_counts()[1]))
print('성소수자 부정 리뷰 갯수: {}'.format(df_queer['label'].value_counts()[0]))
print('성소수자 긍정 리뷰 갯수: {}'.format(df_religion['label'].value_counts()[1]))
print('성소수자 부정 리뷰 갯수: {}'.format(df_religion['label'].value_counts()[0]))
# Out:
# 여성/가족 긍정 리뷰 갯수: 26
# 여성/가족 부정 리뷰 갯수: 198
# 남성 긍정 리뷰 갯수: 14
# 남성 부정 리뷰 갯수: 92
# 지역 긍정 리뷰 갯수: 57
# 지역 부정 리뷰 갯수: 224
# 성소수자 긍정 리뷰 갯수: 2
# 성소수자 부정 리뷰 갯수: 10
# 성소수자 긍정 리뷰 갯수: 22
# 성소수자 부정 리뷰 갯수: 131

# %%
# 긍정, 부정 분포도
def posNneg(df):
    label = ['positive', 'negative']
    index =  np.arange(len(df['label']))
    value = [df['label'].value_counts()[1], df['label'].value_counts()[0]]
    value = [0, df['label'].value_counts()[0]]
    plt.bar(label, value, color=['r', 'b'], alpha=0.5)
    plt.title('Distribution of Pos and Neg', fontsize=15)
    plt.xlabel('label')
    plt.ylabel('count')
    plt.show()

# %%
# 백업용 저장
df_woman.to_csv('./윤석열/윤석열_여성.csv', encoding='utf-8-sig',sep=',', index=False)
df_man.to_csv('./윤석열/윤석열_남성.csv', encoding='utf-8-sig',sep=',', index=False)
df_region.to_csv('./윤석열/윤석열_지역.csv', encoding='utf-8-sig',sep=',', index=False)
df_queer.to_csv('./윤석열/윤석열_성소수자.csv', encoding='utf-8-sig',sep=',', index=False)
df_religion.to_csv('./윤석열/윤석열_종교.csv', encoding='utf-8-sig',sep=',', index=False)

# %%
df_woman = pd.read_csv('./윤석열/윤석열_여성.csv', encoding='utf-8')
df_man = pd.read_csv('./윤석열/윤석열_남성.csv', encoding='utf-8')
df_region = pd.read_csv('./윤석열/윤석열_지역.csv', encoding='utf-8')
df_queer = pd.read_csv('./윤석열/윤석열_성소수자.csv', encoding='utf-8')
df_religion=pd.read_csv('./윤석열/윤석열_종교.csv', encoding='utf-8')

# %%
for i in ex['text']:
    print(i)
# Out:
# 모처럼 호남출신으로 전국구 인물이었던 이낙연 전라도 순천에서 개망신 전라디언들은 경선에 이용후 내쳐버린 불운의 이낙연 정치생명 끝날까 이낙연의 불운은 윤석열 일생일대 최고의 행운
# 아직도 윤석열 두둔하고픈 마음은 1도 없지만 광주출신이고 거의 평생을 전라도 사람으로 살아왔던 사람으로서 한마디 훈수 두건대 호남에 박정희 전두환 박근혜 향수 가진 사람들 여기저기 널렸수다 근데 광주전남 사람 우습게 봐도 유분수지 얼마나 획일적인 사회주의 공산주의자들로 보면
# 민주화 된지가 언제인데 지금까지 투쟁의식 강화니 약화니 그딴소리 나는 거 그니까 광주 호남은 좌적폐들의 해방구 인질이라는 거지 광주시민의 아픔을 수 십년간 이용해 쳐 먹는 윤석열 후보 복합쇼핑센터 문제 제시 않았다면 우리도 계속 속고 살았겠지
# 이나라를 1000년넘게 망쳐온 씹썌갱상도것들이 이번 딱한번 나쁜새끼 이재명지지율이 윤석열보다높다고 호남이 어떻네 저떻네한다 갱상도출신 이재명같은새끼들 제발 역사 공부좀해라 이 갱상도 개새끼들아 니들보다 더 역사에 희생양이었고 옳바른 선택을 해왔던 호남이거덩 지역감정창시자 시키들
# 유사이래 대한민국 최고의 양아치집단 민좃당 호남1500만이 지금껏 다 알고도 속아준걸 모르고 급기야는 세계적인 추문 치부의 주인공 사사오입의 불법적인 후보를 용감하게 들이미는데 호남이 제정신인데 혐죄명이를 찍겠냐 사망자도 당선시키는 대구도 윤석열 찍는걸
# 호남 출신 호남을 짓밟은 반민주 군사독재 살인마 전두환을 추종하는 무당의 힘 아바타 윤석열을 지지하는 호남인은 천벌을 받아 마땅하다 탈당과 지지로 일반화 시켜주면 안된다 배신과 반동으로 규정하고 다시는 호남 팔이 정치행위를 금지시키고 영구제명 출당시켜야한다
# 이재명 싫으면 심상정 찍으면 모를까 자칭 문파 라는 똥파리 처럼 역대 대선후보 중 가장 무식한 윤석열 을 찍을까요 호남 이 똥파리수준 은 아닙니다
# 호남의 민주당은 살기위한 몸부림이고 경상도의 지랄은 호남것 더 뺏어먹기위해 하는 짓거리이고 내용이 다르다 썩꺼져라 호남 찾은 윤석열 특정 정당 장악해 되는 게 있었나
# 호남에서 민주당만 찍어준결과 함량미달들 양산해놨습니다 광주부터 바뀌도록 해볼게요 이번에 윤석열 일단 51 목표로
# 호남 최대도시 광주광역시가 경기도 일개 수원특례시보다 나을 게 없다는게 너무 어이없는데 민주당 저러는 거 진짜 할 말 없다 민주당에게 호남은 뭐야 호남정권 생기면 특혜소리 들을까 눈치보면서 보수정권은 워낙 푸대접하다 이제 윤석열이 뭐 해준대도 민주당이 나서서 발광하면 뭐 어쩌라고
# 국짐당의 이준석 윤석열이 감히 호남에서 지지율 20 이상 운운하고있다 본적을 옮기든지 해야지 수치스러워서 원 객지에 나와 살면서 별별 새끼들이 아무리 호남을 비하하고 중상모략해도 내고향이 호남이라는것이 떳떳하고 자랑스러웠는데 어쩌다 내 고향 민주성지 호남 이 이렇게 됐나
# 호남 낙후의 책임을 더불당 매향노 호남 출신 정치인에게 묻는 건 당연하지만 그렇다고 모든 책임을 저들에게 따지면 호구된다 저들은 그저 친노영패의 마름에 불과하니까 호남낙후 호남차별은 영남패권주의의 산물이다 그럼 영패의 본진이 어디던가 윤석열 앞세운 박정희당 아닌가
# 윤석열이 대구에서 호남을 끌어 안을 때 이재명은 호남에서 신천지 포퓰리즘 타령을 했네 참
# 호남빼고 전국적으로 윤석열에게 뒤지고 있고 인구적은 호남에서 마저도 압도적이지 않은데 무슨 수로 이기지
# 영남 압도적으로 윤석열 후보를 호남 윤석열 후보를 이재명 보다 더 지지하는 것이 동서화합임 부적격 전사범이 민주당이라 무조건 찍는다면 호남은 지역주의 노예로 자인과 고립을 자초 영남의 윤석열 후보를 압도적 지지해도 이번은 지역주의 아닌 상식적 선택으로 평가 받음 이번 대선 특징임
# 김상돈 만평 호남에겐 그동안 뭘해줬니 #뉴스더원 #만평 #호남 #우상호 #윤석열
# 윤석열 호남에 가서 한 말이죠 호남을 얼마나 호구로 보면 저런말을 하겠습니까 호남사람을 벌써 안철수로 넘어간 사람들 많고 안철수는 단일화로 윤석열에게 표 갖다바치겠다고 하고
# 광주에 복합쇼핑몰이 없어서 문제냐 윤석열 지지하는 호남 등신들아 왜 일자리 없다는 얘기 안 하냐 윤석열 저 놈이 정상으로 보이나
# 호남 문파들 목표는 윤석열 51 입니다
# 대구 윤석열 연설 대구와 광주를 연결하는 달빛고속철도를 놓아 영호남이 교류하고 젊은이들 왕래가 있어야 한다 호남이 잘 되는 것이 영남이 잘 되는 것이고 대한민국이 잘 되는 것이다 광주 이재명 연설 광주에 신천지 많다면서요 복합쇼핑몰 그거 필요없음 포퓰리즘임 쓸어버려야 됨
# 이재명 후보는 오늘부터 이틀 동안 민심 바로미터로 불리는 충청을 찾아 한표 호소에 나서고 서해안 라인 유세 이틀째에 나서는 윤석열 후보은 호남을 찾는데 보수정당 후보로선 처음으로 전남 신안군에 있는 김대중 전 대통령 생가를 방문하고 지지 호소에 나섭니다
# 호남지방가서는 김대중팔고 영남가서는 노무현파는 윤석열의 이중성에 속는자들이 바보죠
# 검사가 피해자와 변호인 비난 하는격 호남을 생각한다면 먼저 영남 정권과 지역 차별 부터 조지고 시작해야 정상이지 이게 윤석열식 화법의 특징
# 호남에서 윤석열이 20 이상 먹고 친문들이 이재명에게 등돌리면 득표35 못넘긴다니까
# 현실은 지금 이낙연은 호남을 도덕적으로 고립시키고 대한민국과 국민을 버리고 매국노들 앞잡이 노릇한단 사실을 주지시켜 드립니다 민주당 껍데기를 사랑하는 것과 미래의 윤석열 대통령과의 연합여부를 떠나 현재 적이니 저도 당신에 맞서 최선을 다할 거고 그게 당신에 대한 저의 예우입니다
# 제 지인은 부부 아들 딸 4명 모두 윤석열 찍고 그래도 민주당 찍어야한다는 시부모까지 모시고가 기어코 윤석열 찍게 만들었다고 합니다 사전투표소엔 청년층만 바글바글했다고 노동자 노조 집결해있는 광주 광산구인데 호남 2 30대 청년층 윤석열 지지 현실로 드러난것
# 이재명 신천지 사안도 특검 윤석열 호남 과실 받을때 후보04 호남01 자유03 민주주의 기자05 지역03 지방09 여수07 열차02 특검
# 너님이 더 웃기거든 호남이 뭐 민주당것이라더냐 민주주의의 성지 호남을 하찮은지역으로 민든건 너그덜 민주당이여 윤석열후보님 봐라 진정 호남을 존중하시는걸 쫌 배워 먼저했다고 다 선배가 아니여 진짜가 아니더라도 척이라도 해야 할거 아니냐 너그덜은 준비도 안됐어 써글
# 주진우 라이브 박주선 호남 식자층은 윤석열 지지 김홍걸 이재명 지지에 시간 걸렸을 뿐 호남은 윤석열 응원한 적 없다 다음 뉴스 어이 박군
# 윤석열 인간미 왜 이렇게 많이 오셨나 호남을 호구 취급 그분과 당과는 전혀 다른 태도 왜 이렇게 많이 나오셨나 솔작히 놀랐고 고맙습니다 오늘 이 지지와 성원이 비판과 분노로 바뀌지 않도록 겸손하게 국가 이끌겠다
# 윤석열 호남인이 지켜온 자유민주주의 바로 세우겠다 호남인을 위해 호남인을 죽인 전두환식 자유민주주의라는 단어로 폭행 민주주의라는 단어는 절대 안 씀 박정희 전두환 자유민주주의
# 윤석열 호남 특정정당이 수십년 장악 그래서 된 게 있나 전북 문화 최고지만 경제는 열악 산업 경제 비약적으로 키워야 할 때 전북 8대 공약 발표
# 윤석열 김대중 정신 구현하겠다 호남 끌어안기 광폭 행보
# 주만아 사전투표율 분석 내가 해줄께 호남이 가장 높고 경기가 가장 저조 대구 인천 서울도 평균보다 저조 이 의미기 뭘끼 보수쪽은 윤석열이 말해도 투표 부정 선입견 있어 본투표에 더 많이 해 경기 대구 인천 서울 본투표에 뒤비진다 오늘 사전투표 연령대 다양하게 있었고 노인도 많았어

# %%
import re

# Basic Cleaning Text Function
def CleanText(readData, Num=False, Eng=False):

    # Remove Retweets RT @user_screenname 
    text = re.sub('RT @[\w_]+: ', '', readData)
    text = re.sub('알티', '', text)
    text = re.sub('RT', '', text)

    # Remove Mentions
    text = re.sub('@[\w_]+', '', text)

    # Remove or Replace URL 
    text = re.sub(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", ' ', text) # http로 시작되는 url
    text = re.sub(r"[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{2,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", ' ', text) # http로 시작되지 않는 url
    
    # Remove Hashtag
    text = re.sub('[#]+[0-9a-zA-Z_]+', ' ', text)

    # Remove Garbage Words (ex. &lt, &gt, etc)
    text = re.sub('[&]+[a-z]+', ' ', text)

    # Remove Special Characters
    text = re.sub('[^0-9a-zA-Zㄱ-ㅎ가-힣]', ' ', text)
    
    # Remove newline
    text = text.replace('\n',' ')
    
    if Num is True:
        # Remove Numbers
        text = re.sub(r'\d+',' ',text)
    
    if Eng is True:
        # Remove English 
        text = re.sub('[a-zA-Z]' , ' ', text)

    # Remove multi spacing & Reform sentence
    text = ' '.join(text.split())
       
    return text

# %%
from konlpy.tag import Mecab

# %%
# Preprocessing code with Mecab
#dicpath="/usr/local/lib/mecab/dic/mecab-ko-dic"
mecab = Mecab(r"C:/mecab/mecab-ko-dic") # Mecab User Dic Path

def preprocessing_mecab(readData):
    
    #### Clean text
    sentence = CleanText(readData)
    
    #### Tokenize
    morphs = mecab.pos(sentence)
    
    JOSA = ["JKS", "JKC", "JKG", "JKO", "JKB", "JKV", "JKQ", "JX", "JC"] # 조사
    SIGN = ["SF", "SE", "SSO", "SSC", "SC", "SY"] # 문장 부호
    TERMINATION = ["EP", "EF", "EC", "ETN", "ETM"] # 어미
    SUPPORT_VERB = ["VX"] # 보조 용언
    NUMBER = ["SN"]
    
    # Remove JOSA, EOMI, etc
    morphs[:] = (morph for morph in morphs if morph[1] not in JOSA+SIGN+TERMINATION+SUPPORT_VERB)
        
    # Remove length-1 words  
    morphs[:] = (morph for morph in morphs if not (len(morph[0]) == 1))
    
    # Remove Numbers
    morphs[:] = (morph for morph in morphs if morph[1] not in NUMBER)
   
    # Result pop-up
    result = []
    for morph in morphs:
        result.append(morph[0])
        
    return result

# %%
df_woman['tokenized'] = df_woman['text'].apply(lambda x: preprocessing_mecab(x))
df_man['tokenized'] = df_man['text'].apply(lambda x: preprocessing_mecab(x))
df_region['tokenized'] = df_region['text'].apply(lambda x: preprocessing_mecab(x))
df_queer['tokenized'] = df_queer['text'].apply(lambda x: preprocessing_mecab(x))
df_religion['tokenized'] = df_religion['text'].apply(lambda x: preprocessing_mecab(x))

# %%
token_woman = df_woman['tokenized']
token_man = df_man['tokenized']
token_region = df_region['tokenized']
token_queer = df_queer['tokenized']
token_religion = df_religion['tokenized']

# %%
# tokenizing
# stopwords list
stop_words = pd.read_csv('./한국어불용어100.txt', sep = "\t", engine='python')
stop_words = list(stop_words["word"])
stopwords = ['윤석열','된다고','합니다', '입니다', '진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는','생겼', '인데', '해도', '된다', '이거','그리고','나오','이번', '때문', '그러', '그런', '진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는','생겼', '인데', '해도', '된다', '이거','한다', '세요', '합니다', '입니다', 'ㅋㅋㅋ', 'ㅋㅋ','그냥', '한다는', '해서', '인데', '라면', '만들', '라니']
stopwords = stopwords+stop_words
stopwords.remove('여자')

# %%
print(stopwords)
# Out:
# ['윤석열', '된다고', '합니다', '입니다', '진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는', '생겼', '인데', '해도', '된다', '이거', '그리고', '나오', '이번', '때문', '그러', '그런', '진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는', '생겼', '인데', '해도', '된다', '이거', '한다', '세요', '합니다', '입니다', 'ㅋㅋㅋ', 'ㅋㅋ', '그냥', '한다는', '해서', '인데', '라면', '만들', '라니', '이', '있', '하', '것', '들', '그', '되', '수', '이', '보', '않', '없', '나', '사람', '주', '아니', '등', '같', '우리', '때', '년', '가', '한', '지', '대하', '오', '말', '일', '그렇', '위하', '때문', '그것', '두', '말하', '알', '그러나', '받', '못하', '일', '그런', '또', '문제', '더', '사회', '많', '그리고', '좋', '크', '따르', '중', '나오', '가지', '씨', '시키', '만들', '지금', '생각하', '그러', '속', '하나', '집', '살', '모르', '적', '월', '데', '자신', '안', '어떤', '내', '내', '경우', '명', '생각', '시간', '그녀', '다시', '이런', '앞', '보이', '번', '나', '다른', '어떻', '개', '전', '들', '사실', '이렇', '점', '싶', '말', '정도', '좀', '원', '잘', '통하', '소리', '놓']

# %%
category = [token_woman, token_man, token_region, token_queer, token_religion]

# %%
# 단어 빈도수 생성
def word_frequency(token):
    n_corpus = []
    for t in token:
        for j in t:
            if j not in stopwords:
                n_corpus.append(j)

    count = collections.Counter(n_corpus) 
    most = count.most_common() # 빈도 수 순으로 추출 
    x, y= [], [] 
    for word,count in most[:40]: 
        x.append(word) 
        y.append(count)
    #plt.rc('font',family='NanumGothic.ttf')
    plt.rcParams['font.family'] = "NanumGothic"
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(10,10)) 
    sns.barplot(x=y,y=x)

# %%
# 여성/가족, 남성, 지역, 성소수자, 종교
for i in category:
    word_frequency(i)

# %%
# 워드 클라우드 생성
def make_wordcloud(token):
    n_corpus = []
    for t in token:
        for j in t:
            if j not in stopwords:
                n_corpus.append(j)
    font_path = 'C:/Users/Erin/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.ttf'
    wordcloud = WordCloud(font_path=font_path,
                        background_color="black",
                        stopwords=stopwords, 
                        max_words=100, 
                        # max_font_size=30,
                        width=500,
                        height=500, 
                        random_state=1,
                        scale=3).generate(' '.join(n_corpus))
    fig = plt.figure(1, figsize=(8,8)) 
    plt.imshow(wordcloud, interpolation='bilinear')
    #plt.axis('off')
    plt.show()

# %%
for i in category:
    make_wordcloud(i)
